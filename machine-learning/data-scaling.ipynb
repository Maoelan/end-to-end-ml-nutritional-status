# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
data = pd.read_excel('data scaling.xlsx')
data
# Out:
#                     NIK                     Nama  BB Lahir  TB Lahir  Berat  \
# 0    5202080606192554              KEISYA PUTRI        3.1        50    9.0
# 1    5202084301202131               NUR SYUHADA        3.2        48    5.7
# 2    5202081307190004                HAIDAR ALI        2.7        51    8.1
# 3    5202084609190008    AMELIA MUTIARA IBRAHIM        2.9        49    7.3
# 4    5202080812190007         M. SAPIK AZRULLAH        3.0        50    6.3
# ..                  ...                      ...       ...       ...    ...
# 241  5202080812201000            MUHAMAD GILANG        2.7        48    7.8
# 242  5202082905190133         SUKMADANI PRAYASA        3.1        51   11.2
# 243  5202804711212960            ZAFIRA NOVIANI        2.6        49    6.9
# 244  5202083103196754                  M. ZIKRI        3.0        49   11.7
# 245  5202806503180011             ERLIN MARLINA        3.0        48   12.4
#
#      Tinggi Label Aktual
# 0      66.0   GIZI LEBIH
# ...

# %%
columns_to_scale = ['BB Lahir', 'TB Lahir', 'Berat', 'Tinggi']

# %%
scaler = MinMaxScaler()

# %%
data[columns_to_scale] = scaler.fit_transform(data[columns_to_scale])

# %%
data.to_excel('data true final.xlsx', index=False)
